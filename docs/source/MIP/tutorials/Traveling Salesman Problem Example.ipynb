# %% [markdown]
# # Graph Theory Class assignment
#
# ## Try me
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ffraile/operations-research-notebooks/blob/main/docs/source/MIP/tutorials/Traveling%20Salesman%20Problem%20Example.ipynb)[![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ffraile/operations-research-notebooks/main?labpath=docs%2Fsource%2FMIP%2Ftutorials%2FTraveling%20Salesman%20Problem%20Example.ipynb)
#
# ## Requirements
#
# You need to install Networkx in your runtime, so make sure you run this script if not already installed.
#
# Note that the install line includes the *extra* option to install additional packages which are useful to work with
# Networkx.

# %%
# !pip install networkx[default]
# !pip install ipython
# !pip install pandas
# Out:
# Requirement already satisfied: networkx[default] in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (3.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from networkx[default]) (1.24.1)
# Requirement already satisfied: scipy>=1.8 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from networkx[default]) (1.10.0)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from networkx[default]) (3.7.0)
# Requirement already satisfied: pandas>=1.3 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from networkx[default]) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.4->networkx[default]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from pandas>=1.3->networkx[default]) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->networkx[default]) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipython in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (8.8.0)
# Requirement already satisfied: backcall in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (2.14.0)
# Requirement already satisfied: stack-data in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (5.8.1)
# Requirement already satisfied: colorama in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: six>=1.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Additionally, you need to install osmnx and Folium:

# %%
# !apt-get -qq install -y libspatialindex-dev
# !pip install osmnx
# !pip install folium
# Out:
# "apt-get" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# Requirement already satisfied: osmnx in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (1.3.0)
# Requirement already satisfied: geopandas>=0.12 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (0.12.2)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (3.7.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (3.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (1.24.1)
# Requirement already satisfied: pandas>=1.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (1.5.3)
# Requirement already satisfied: pyproj>=3.4 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.8 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (2.8.2)
# Requirement already satisfied: requests>=2.28 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (2.28.2)
# Requirement already satisfied: Shapely>=2.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from osmnx) (2.0.1)
# Requirement already satisfied: fiona>=1.8 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from geopandas>=0.12->osmnx) (1.9.1)
# Requirement already satisfied: packaging in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from geopandas>=0.12->osmnx) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.5->osmnx) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.5->osmnx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.5->osmnx) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.5->osmnx) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.5->osmnx) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from matplotlib>=3.5->osmnx) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from pandas>=1.5->osmnx) (2022.7.1)
# Requirement already satisfied: certifi in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from pyproj>=3.4->osmnx) (2022.12.7)
# Requirement already satisfied: six>=1.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from python-dateutil>=2.8->osmnx) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from requests>=2.28->osmnx) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from requests>=2.28->osmnx) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from requests>=2.28->osmnx) (1.26.14)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (22.2.0)
# Requirement already satisfied: click~=8.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from fiona>=1.8->geopandas>=0.12->osmnx) (65.5.1)
# Requirement already satisfied: colorama in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from click~=8.0->fiona>=1.8->geopandas>=0.12->osmnx) (0.4.6)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: folium in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from folium) (1.24.1)
# Requirement already satisfied: requests in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from folium) (2.28.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from jinja2>=2.9->folium) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from requests->folium) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from requests->folium) (2022.12.7)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Finally, you need to install scikit-learn to use the Travelinsg Salesman Problem algorithm. Note that this is already pre-installed in Google Colabs.

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (1.2.1)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.17.3 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from scikit-learn) (1.24.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\franc\pycharmprojects\operations-research-notebooks\venv\lib\site-packages (from scikit-learn) (3.1.0)

# %% [markdown]
# #### Create a map
# Create a network from a map using the ```graph_from_bbox``` function:
#
# - ```graph_from_bbox```: Creates a graph within four points of a bounding box, specifying the ```north``` northern
# latitude of the bounding box, the ```south``` southern latitude of bounding box, the ```east``` eastern longitude of
# the bounding box and the ```west``` western longitude of the bounding box.
#
# Use google maps to get two markers around the area of interest of your assignment, it can be your neighbourhood, or anywhere in the world, but EDEM. Then modify the coordinates of the map in the following snippet:

# %%
import networkx as nx
import osmnx as ox
import pandas as pd
# get two markers from google maps and modify the coordinates around EDEM 
# e.g. with two markers around EDEM: Latitude, Longitude
# North-west marker
# 39.468370277652426, -0.33528989341188187
# 39.47953561643489, -0.38186895348265193
# South east marker
# 39.45963084307057, -0.3184406656568226
# 39.47953561643489, -0.38186895348265193
# 39.469446, -0.365671


G_nx = ox.graph_from_bbox(north=39.468370277652426, 
                          south=39.45963084307057, 
                          east=-0.3184406656568226, 
                          west=-0.33528989341188187)

# %% [markdown]
# #### Rendering the map
# The function plot_graph_folium uses [Folium](https://python-visualization.github.io/folium/) to render the map in an
# interactive map:

# %%
m1 = ox.plot_graph_folium(G_nx)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44b1410d26c35e12c33e0569ded10850 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44b1410d26c35e12c33e0569ded10850&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44b1410d26c35e12c33e0569ded10850 = L.map(
#                 &quot;map_44b1410d26c35e12c33e0569ded10850&quot;,
#                 {
#                     center: [39.4639094611789, -0.3278036899421907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78a9431f1ec01e6436d3dec757a9d522 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44b1410d26c35e12c33e0569ded10850);
#
#
#             var poly_line_ef7bdee6f378e573413e67c374b34d6a = L.polyline(
#                 [[39.4599649, -0.332837], [39.459934, -0.332748], [39.4599211, -0.3327041], [39.4598745, -0.3326031], [39.4597856, -0.3325184]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44b1410d26c35e12c33e0569ded10850);
#
#
#             var poly_line_8fe27c87d9026166c51b75b66501ff7c = L.polyline(
#                 [[39.4599649, -0.332837], [39.4600666, -0.3328162], [39.4601162, -0.3327979]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44b1410d26c35e12c33e0569ded10850);
#
#
#             var poly_line_a7b79c60eb616ce575e1273d30306797 = L.polyline(
#                 [[39.4627739, -0.3302816], [39.4628011, -0.3302036], [39.4628188, -0.3301587]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44b1410d26c35e12c33e0569ded10850);
#
#
#             var poly_line_e1a8fab1c6550913a99cce74c66c0fb9 = L.polyline(
#                 [[39.4627739, -0.3302816], [39.4627364, -0.3302669], [39.4627131, -0.3302614]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44b1410d26c35e12c33e0569ded10850);
#
#
#             var poly_line_3b6a01aa7e889e3c1b0569342c93910a = L.polyline(
#                 [[39.4624871, -0.3302833], [39.4624184, -0.3303942], [39.462211, -0.3306393], [39.4616497, -0.3312542], [39.461406, -0.3315295], [39.4606956, -0.3323445], [39.4604718, -0.3326015]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_44b1410d26c35e12c33e0569ded1

# %% [markdown]
# #### distance.nearest_node
# When you work on a graph, you could click on a point in the map that is not necessarily an edge in the graph, so
# to be able to process its coordinates, you first need to find the node in the graph that is closest to the point. You can use the  [nearest_node](https://osmnx.readthedocs.io/en/stable/osmnx.html#osmnx.distance.nearest_nodes) function for this purpose, it returns the id of the node that is closest to the point you pass as an argument so
# that you can later use the node in the algorithms. Let see with an example, using the coordinates of EDEM extracted from Google Maps:

# %%
edem_latitude = 39.46211739713285
edem_longitude = -0.3288013882525529
nearest_node = ox.distance.nearest_nodes(G_nx, X=edem_longitude, Y=edem_latitude)
nearest_node
# Out:
# 6629446599

# %% [markdown]
# #### Traveling salesman
# Now, we want to calculate the optimal route to visit a set of points in the map solving the traveling salesman problem.
# The function [traveling_salesman_problem](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.approximation.traveling_salesman.traveling_salesman_problem.html) solves this problem in any graph. As you can read in the documentation of this function, we need to specify which attribute of the edges in the graph specifies the weight used to calculate distances in the TSP problem. The following code cells shows that the attribute is actually called length:

# %%
# Get the edges and their data and put the data in a dataframe
nx.to_pandas_edgelist(G_nx)
# Out:
#            source       target  oneway       osmid junction lanes   length  \
# 0        88356838   1800312429    True   652764215      NaN   NaN   34.784
# 1        88356838   1339801172    True   806146193      NaN   NaN   17.184
# 2        88428374   5499046929    True   115600553      NaN   NaN   11.675
# 3        88428374  10139283393    True   115600559      NaN   NaN    6.991
# 4        88428405   6338241732    True    13960791      NaN   NaN  299.907
# ...           ...          ...     ...         ...      ...   ...      ...
# 1479  10285307342  10285307326   False  1111546975      NaN   NaN   10.080
# 1480  10285307342  10285307341   False  1111546975      NaN   NaN   31.438
# 1481  10285307342  10285307341   False  1111546974      NaN   NaN   59.922
# 1482  10285307342  10285307341   False  1111546974      NaN   NaN   57.854
# 1483  10561780713   4077510727   False  1132710257      NaN   NaN    9.232
#
#      access                                           geometry reversed  \
# 0       NaN  LINESTRING (-0.332837 39.4599649, -0.332748 39...    False
# 1       NaN  LINESTRING (-0.332837 39.4599649, -0.3328162 3...    False
# 2       NaN  LINESTRING (-0.3302816 39.4627739, -0.3302036 ...    False
# 3       NaN  LINESTRING (-0.3302816 39.4627739, -0.3302669 ...    False
# 4       NaN  LINESTRING (-0.3302833 39.4624871, -0.3303942 ...    False
# ...     ...                                                ...      ...
# 1479    NaN                                                NaN    False
# 1480    NaN                                                NaN     True
# 1481    NaN  LINESTRING (-0.3239924 39.4636226, -0.3241564 ...    False
# 1482    NaN  LINESTRING (-0.3239924 39.4636226, -0.3238383 ...     True
# 1483    NaN                                                NaN     True
#
#      service                                 name maxspeed      highway
# 0        NaN                   Plaça de les Hores      NaN  residential
# 1        NaN  Carrer del Doctor Josep Juan Dòmine      NaN    secondary
# 2        NaN   Plaça de la Setmana Santa Marinera      NaN  residential
# 3        NaN  Carrer del Doctor Josep Juan Dòmine      NaN  residential
# 4        NaN  Carrer del Doctor Josep Juan Dòmine      NaN    secondary
# ...      ...                                  ...      ...          ...
# 1479     NaN                                  NaN      NaN      footway
# 1480     NaN                                  NaN      NaN      footway
# 1481     NaN                                  NaN      NaN      footway
# 1482     NaN                                  NaN      NaN      footway
# 1483     NaN                                  NaN      NaN      footway
#
# [1484 rows x 14 columns]

# %% [markdown]
# #### Select points
# Now you are ready to select different points in the map and use them in the TSP problem. Use again google maps to select some points (at least 4) in the map and add the latitudes and longitudes in the following cell. Remember you need to get the nearest nodes for all of them. The following example calculates the TSP between EDEM and a nearby museum

# %%
latitudes = (39.46211739713285, 39.46329739674903)
longitudes = (-0.3288013882525529, -0.33194815644130443)
nearest_nodes = ox.distance.nearest_nodes(G_nx, X=longitudes, Y=latitudes)
print(nearest_nodes)
route = nx.approximation.traveling_salesman_problem(G_nx.to_undirected(), nodes=nearest_nodes, weight="length")
ox.plot_route_folium(G_nx, route, route_map=m1, weight=7, color='black')
# Out:
# [6629446599, 430152412]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_697d6dce8628e0451c3ff0f646f62a7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_697d6dce8628e0451c3ff0f646f62a7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_697d6dce8628e0451c3ff0f646f62a7f = L.map(
#                 &quot;map_697d6dce8628e0451c3ff0f646f62a7f&quot;,
#                 {
#                     center: [39.4639094611789, -0.3278036899421907],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_512abb0818a14982683430f438a3f07a = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_697d6dce8628e0451c3ff0f646f62a7f);
#
#
#             var poly_line_12c3ea77b813d5f7fbb4346c4d384fff = L.polyline(
#                 [[39.4599649, -0.332837], [39.459934, -0.332748], [39.4599211, -0.3327041], [39.4598745, -0.3326031], [39.4597856, -0.3325184]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_697d6dce8628e0451c3ff0f646f62a7f);
#
#
#             var poly_line_a752cf8ef0a94e9cf3e3077bead043f2 = L.polyline(
#                 [[39.4599649, -0.332837], [39.4600666, -0.3328162], [39.4601162, -0.3327979]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_697d6dce8628e0451c3ff0f646f62a7f);
#
#
#             var poly_line_cb571265c2a3f153c68a58fcdd20c0f4 = L.polyline(
#                 [[39.4627739, -0.3302816], [39.4628011, -0.3302036], [39.4628188, -0.3301587]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_697d6dce8628e0451c3ff0f646f62a7f);
#
#
#             var poly_line_1e3897f5abcfc046068be060f1cf0d37 = L.polyline(
#                 [[39.4627739, -0.3302816], [39.4627364, -0.3302669], [39.4627131, -0.3302614]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_697d6dce8628e0451c3ff0f646f62a7f);
#
#
#             var poly_line_e5c17cbc75e3af9e72a374f525dbc959 = L.polyline(
#                 [[39.4624871, -0.3302833], [39.4624184, -0.3303942], [39.462211, -0.3306393], [39.4616497, -0.3312542], [39.461406, -0.3315295], [39.4606956, -0.3323445], [39.4604718, -0.3326015]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_697d6dce8628e0451c3ff0f646f6

# %% [markdown]
# # Planning the Construction of homes
# On a housing estate on the Alicante coastline, two types of homes are being built: apartments and penthouses, whose prices are $p_1$ and $p_2$ M€ respectively. The curve of demand for apartments is $d_1 = 40 – 2p_1$ and $d_2 = 150 – 3p_2$ for penthouses.
# The builder calculated that, owing to the orders that he has already sent to his raw materials suppliers, it is worth building 15 times more apartments than penthouses. He has also calculated that building an apartment costs him 5M€, while a penthouse costs him 3M€. Knowing that the builder has a budget of 350 M€, work out the following:
#
# **a)** Write an NLP to calculate the optimal prices for apartments and penthouses.
#
# Our decision variables are going to be the prices of the apartments and penthouses:
# - $p_1$: Selling price of apartments
# - $p_2$: Selling price of penthouses
#
# We need to calculate the optimal prices that maximizes the profit, which is the product of the demand times the difference between the selling prices and the cost of building:
#
# $\max z = (p_1-5)*d_1 + (p_2-3)*d_2$
#
# Plugging in the expression of the curve of demand yields:
#
# $\max z = (p_1-5)(40-2p_1) + (p_2-3)(150-3p_2) = -2p_1^2-3p_2^2+50p_1+159p_2-650$
#
# Note that the latter only depends on the decision variables.
#
# **Budget constraint:**
# Now, we also need to take into account the budget constraint, which is given by the cost of building times the demand:
#
# $5*d_1+3*d_2 \leq 350$
#
# Again, plugging in the expression of the curve of demand yields:
#
# $5(40-2p_1)+3(150-3p_2) \leq 350 \rightarrow -10p_1-9p2+300 \leq 0$
#
#
# **Demand constraint:**
# Finally, we need to take into account the demand constraint, calculated by the builder, stating that the number of apartments must be at least 15 times the number of penthouses:
#
# $15*d_2 \geq d_1$
#
# Or again, plugging in the expression of the curve of demand:
#
# $15(150-3p_2) \leq (40-2p_1)$
#
# If we put everything together, and express the constraints in the canonical form, we get:
#
# $\max z = (p_1-5)(40-2p_1) + (p_2-3)(150-3p_2) = -2p_1^2-3p_2^2+50p_1+159p_2-650$
#
# $\text{s.t}$
#
# $5(40-2p_1)+3(150-3p_2) \leq 350 \rightarrow -10p_1-9p2+300 \leq 0$
#
# $15(150-3p_2) \leq (40-2p_1) \rightarrow -2p_1-45p_2+2210 \leq 0$
#
# $p_1, p_2 \geq 0$
#
#
# **b)** Write the Kuhn Tucker conditions of the NLP problem:
#
# The Lagrangian is:
#
# $L = -2p_1^2-3p_2^2+50p_1+159p_2-650 + \lambda_1\left(-10p_1-9p2+300\right) + \lambda_2\left(-2p_1-45p_2+2210\right)$
#
# **Gradient condition:**
#
# $\nabla(L)=0$
#
# $\dfrac{dL}{dq_1} = -4p_1+50-10\lambda_1-2\lambda_2 = 0$
#
# $\dfrac{dL}{dq_2} = -6p_2+159-9\lambda_1-45\lambda_2 = 0$
#
# **Feasibility Condition:**
#
# $-10p_1-9p_2+300 \leq 0$
#
# $-2p_1-45p_2+2210 \leq 0$
#
# **Orthogonality Condition:**
#
# $\lambda_1·(-10p_1-9p2+300) = 0$
#
# $\lambda_2·(-2p_1-45p_2+2210) = 0$
#
# **Non-negativity condition:**
#
# $p_1, p_2 \geq 0$
#
# $\lambda_1, \lambda_2 \leq 0$

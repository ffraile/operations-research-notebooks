# %% [markdown]
# ## Try me
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ffraile/operations-research-notebooks/blob/main/docs/source/CLP/templates/first%20assignment%20template.ipynb)[![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/ffraile/operations-research-notebooks/main?labpath=docs%2Fsource%2FCLP%2Ftemplates%2Ffirst%20assignment%20template.ipynb)
#
# # Useful tutorials
# - [Working with Markdown](https://operations-research.readthedocs.io/en/latest/Introduction/libraries/Working%20With%20Markdown%20Cells.html): Explains how to use Markdown in your problem description
# - [Graphic solution](https://operations-research.readthedocs.io/en/latest/Introduction/libraries/Working%20With%20Markdown%20Cells.html) Explains how to represent the feasibility region in Python and the main functions involved
# - [Numpy Tutorial](https://operations-research.readthedocs.io/en/latest/Introduction/libraries/Numpy%20tutorial.html) Full tutorial on Numpy (library for numeric manipulation)
# - [Matplotlib Tutorial](https://operations-research.readthedocs.io/en/latest/Introduction/libraries/Matplotlib%20tutorial.html) Full tutorial on Matplotlib (library to plot results)
#
#  > ☝ Note to students: Remove this cell when you are done with your assignment

# %% [markdown]
# # Problem Description
#
# ## Introduction to the Problem Domain
#
# (Provide a brief introduction to the domain of your problem. Explain why it's important or interesting, and how linear programming applies to it, the relevance of solving the problem and potential impact of solutions. Aim for at least 1000 characters.)
#
# ## Specific Problem Definition
#
# (Describe the specific problem within the domain you're addressing. Describe What do you need to maximize or minimize (objective),
# What actions can you take (decision varibles),
# What are the limitations on these actions (constraints). Aim for at least 500 characters.)
#
# ## Decision Variables
#
# - **Variable 1 (e.g., $x_1$):** (Define the first decision variable and its role in the problem.)
# - **Variable 2 (e.g., $$x_2$):** (Define the second decision variable and its role in the problem.)
#
# ## Objective Function
#
# (Describe the objective function, including what you're trying to maximize or minimize. Present the mathematical representation of the objective function.)
#
# ## Problem Model
#
# ### Objective Function
#
# - **Objective:** (State the objective function in mathematical terms.)
#
# ### Constraints
#
# (List at least four constraints that define the feasible region. Provide a brief explanation and mathematical representation for each.)
#
# 1. **Constraint 1:** (Description and formula)
# 2. **Constraint 2:** (Description and formula)
# 3. ...
# 4. ...
#
# ## Data Collection
#
# (Explain the data collection process required for defining the problem coefficients. Discuss the sources, methods, and any assumptions made.)
#
# ---
#
# **Note to Students:** Replace the placeholder text with your specific information. Ensure your markdown presentation is clear, well-organized, and easy to understand.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Define the range for x (decision variable 1)
x = np.linspace(0, 5000, 10000)  # Adjust the range and resolution as needed

#1. CONSTRAINT DEFINITION
# Define the constraints as functions of x (second variable as a function of the first)
# e.g. for x1/7500 + x2/6000 <= 1 type:
# y1 = (1 - (x/7500))*6000
# If you need a horixontal line, you can add a constant to a zero array, e.g
# y4 = 5000 + x*0  (Horizontal line at y=5000)

#2. CONSTRAINT REPRESENTATION
# Plot the constraints using plt.plot(x, y), use latex notation to label them
#e.g. plt.plot(x, y1, label=r'$x_{1}/7500 + x_{2}/6000 \leq 1$')


#3. FEASIBILITY REGION
#3.1 CALCULATE UPPER AND LOWER BOUNDS
# Now, to draw the feasibility region you need to take into account that
# for constraints of type less or equal, feasible values will be below the
# constraints.
# For these type of constraints, we will use the function np.minimum() to create
# new lines that determine the minimum value of the constraints (which will
# correspond to the upper bound)
# e.g. y5 = np.minimum(y4, y1)
# For constraints of type greater or equal, feasible values will be above the
# constraints, so we will use the np.maximum() function to determine the lower
# bound of the feasibility region
# e.g. y6 = np.maximum(y3, y2)

# FILL THE REGION
# Now, use the fill_between function to fill the area between the upper bound
# and lower bound of the feasibility region
#e.g. plt.fill_between(x, y5, y6, where=x <= 4000, color='grey', alpha=0.5)

#4. FORMAT YOUR PLOT
#4.1 Label the axes using xlabel() and ylabel()
#e.g. plt.xlabel(r'$x_{1}$')
#plt.ylabel(r'$x_{2}$')

#4.1 Add a legend with legend()
#plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0. )


#5. PLOT THE OBJECTIVE FUNCTION
#5.1  As with the constraints, create a new line with a constant value for the
# objective variabl and add it to your solution.
#5.2 Now, you can either try to solve the problem visually (determine which vertex)
# of the feasibility region is the optimal solution or analytically (try all
# vertices and determine the optimal value). Plug in the value of z obtained in
#5.1 and run again your script.

#6. Show the plot ()
plt.show()
